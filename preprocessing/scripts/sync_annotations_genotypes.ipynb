# %%
import os
import pandas as pd
import numpy as np
import torch

# %%
GENOTYPE_DIR = "/gpfs/commons/groups/knowles_lab/vmazeeva/BigBrain/Processed/genotypes"
ANNOTATIONS_DIR = "/gpfs/commons/groups/knowles_lab/vmazeeva/BigBrain/Processed/annotations_raw"

# %%
for chrom in range(1, 23):
    for file in os.listdir(os.path.join(GENOTYPE_DIR, f"chr{chrom}")):
        if file.endswith(".tsv.gz"):
